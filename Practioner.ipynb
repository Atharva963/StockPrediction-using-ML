# %%
# !pip install tensorflow
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\athar\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\clang\\native\\libclang.dll'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/80/6f/57d36f6507e432d7fc1956b2e9e8530c5c2d2bfcd8821bcbfae271cd6688/tensorflow-2.14.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached tensorflow-2.14.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# ...
#   Obtaining dependency information for tensorflow-intel==2.14.0 from https://files.pythonhosted.org/packages/ad/6e/1bfe367855dd87467564f7bf9fa14f3b17889988e79598bc37bf18f5ffb6/tensorflow_intel-2.14.0-cp311-cp311-win_amd64.whl.metadata
# ...

# %%
# !pip install keras
# Out:
# ...
#   Obtaining dependency information for keras from https://files.pythonhosted.org/packages/fe/58/34d4d8f1aa11120c2d36d7ad27d0526164b1a8ae45990a2fede31d0e59bf/keras-2.14.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.7 MB 2.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.5/1.7 MB 5.2 MB/s eta 0:00:01
#    -------------------- ------------------- 0.9/1.7 MB 6.2 MB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.7 MB 5.7 MB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.7 MB 5.9 MB/s eta 0:00:01
#    ------------------------------- -------- 1.3/1.7 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.2 MB/s eta 0:00:00
# ...

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import yfinance as yf

# %%
#Importing Data From Yfinance

# %%
# ticker = "AAPL"
# start_date = "2022-10-10"
# end_date = "2023-10-10"

# data = yf.download(ticker, start=start_date , end = end_date )
# print(data)
stcok = yf.Ticker("AAPL")

# %%
stock = stock.history(period="max")

# %%
stock
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.099450    0.099882    0.099450    0.099450
# 1980-12-15 00:00:00-05:00    0.094694    0.094694    0.094261    0.094261
# 1980-12-16 00:00:00-05:00    0.087775    0.087775    0.087343    0.087343
# 1980-12-17 00:00:00-05:00    0.089504    0.089937    0.089504    0.089504
# 1980-12-18 00:00:00-05:00    0.092099    0.092532    0.092099    0.092099
# ...                               ...         ...         ...         ...
# 2023-10-10 00:00:00-04:00  178.100006  179.720001  177.949997  178.389999
# 2023-10-11 00:00:00-04:00  178.199997  179.850006  177.600006  179.800003
# 2023-10-12 00:00:00-04:00  180.070007  182.339996  179.039993  180.710007
# 2023-10-13 00:00:00-04:00  181.419998  181.929993  178.139999  178.850006
# 2023-10-16 00:00:00-04:00  176.750000  179.080002  176.509995  178.720001
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
stock.index
# Out:
# DatetimeIndex(['1980-12-12 00:00:00-05:00', '1980-12-15 00:00:00-05:00',
#                '1980-12-16 00:00:00-05:00', '1980-12-17 00:00:00-05:00',
#                '1980-12-18 00:00:00-05:00', '1980-12-19 00:00:00-05:00',
#                '1980-12-22 00:00:00-05:00', '1980-12-23 00:00:00-05:00',
#                '1980-12-24 00:00:00-05:00', '1980-12-26 00:00:00-05:00',
#                ...
#                '2023-10-03 00:00:00-04:00', '2023-10-04 00:00:00-04:00',
#                '2023-10-05 00:00:00-04:00', '2023-10-06 00:00:00-04:00',
#                '2023-10-09 00:00:00-04:00', '2023-10-10 00:00:00-04:00',
#                '2023-10-11 00:00:00-04:00', '2023-10-12 00:00:00-04:00',
#                '2023-10-13 00:00:00-04:00', '2023-10-16 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=10801, freq=None)

# %%
#Cleaning And Visualizing Data

# %%
stock.plot.line(y="Close",use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
# del stock["Dividends"]
# del stock["Stock Splits"]

# %%
stock["Tomorrow"] = stock["Close"].shift(-1)

# %%
stock
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.099450    0.099882    0.099450    0.099450
# 1980-12-15 00:00:00-05:00    0.094694    0.094694    0.094261    0.094261
# 1980-12-16 00:00:00-05:00    0.087775    0.087775    0.087343    0.087343
# 1980-12-17 00:00:00-05:00    0.089504    0.089937    0.089504    0.089504
# 1980-12-18 00:00:00-05:00    0.092099    0.092532    0.092099    0.092099
# ...                               ...         ...         ...         ...
# 2023-10-10 00:00:00-04:00  178.100006  179.720001  177.949997  178.389999
# 2023-10-11 00:00:00-04:00  178.199997  179.850006  177.600006  179.800003
# 2023-10-12 00:00:00-04:00  180.070007  182.339996  179.039993  180.710007
# 2023-10-13 00:00:00-04:00  181.419998  181.929993  178.139999  178.850006
# 2023-10-16 00:00:00-04:00  176.750000  179.080002  176.509995  178.720001
#
#                               Volume  Stock Splits    Tomorrow
# Date
# ...

# %%
stock["Target"]= (stock["Tomorrow"] > stock["Close"]).astype(int)

# %%
stock
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.099450    0.099882    0.099450    0.099450
# 1980-12-15 00:00:00-05:00    0.094694    0.094694    0.094261    0.094261
# 1980-12-16 00:00:00-05:00    0.087775    0.087775    0.087343    0.087343
# 1980-12-17 00:00:00-05:00    0.089504    0.089937    0.089504    0.089504
# 1980-12-18 00:00:00-05:00    0.092099    0.092532    0.092099    0.092099
# ...                               ...         ...         ...         ...
# 2023-10-10 00:00:00-04:00  178.100006  179.720001  177.949997  178.389999
# 2023-10-11 00:00:00-04:00  178.199997  179.850006  177.600006  179.800003
# 2023-10-12 00:00:00-04:00  180.070007  182.339996  179.039993  180.710007
# 2023-10-13 00:00:00-04:00  181.419998  181.929993  178.139999  178.850006
# 2023-10-16 00:00:00-04:00  176.750000  179.080002  176.509995  178.720001
#
#                               Volume  Stock Splits    Tomorrow  Target
# ...

# %%
#Here we can add The date from which we want the data 
stock = stock.loc["2022-01-01":].copy()

# %%
stock
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2022-01-03 00:00:00-05:00  176.052746  181.052279  175.933951  180.190964
# 2022-01-04 00:00:00-05:00  180.804762  181.111662  177.329832  177.904037
# 2022-01-05 00:00:00-05:00  177.814975  178.369376  172.894644  173.171844
# 2022-01-06 00:00:00-05:00  170.974007  173.548028  169.924603  170.281006
# 2022-01-07 00:00:00-05:00  171.162131  172.399639  169.320719  170.449326
# ...                               ...         ...         ...         ...
# 2023-10-10 00:00:00-04:00  178.100006  179.720001  177.949997  178.389999
# 2023-10-11 00:00:00-04:00  178.199997  179.850006  177.600006  179.800003
# 2023-10-12 00:00:00-04:00  180.070007  182.339996  179.039993  180.710007
# 2023-10-13 00:00:00-04:00  181.419998  181.929993  178.139999  178.850006
# 2023-10-16 00:00:00-04:00  176.750000  179.080002  176.509995  178.720001
#
#                               Volume  Stock Splits    Tomorrow  Target
# ...

# %%
#Training Initial ML Model

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100 , min_samples_split=100 , random_state=1)

train = stock.iloc[:-100]
test = stock.iloc[-100:]

predictors = ["Close" , "Volume" , "Open" , "High" , "Low"]
model.fit(train[predictors] , train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd

preds = pd.Series(preds, index=test.index)
# Out:
# Date
# 2023-05-24 00:00:00-04:00    1
# 2023-05-25 00:00:00-04:00    1
# 2023-05-26 00:00:00-04:00    0
# 2023-05-30 00:00:00-04:00    0
# 2023-05-31 00:00:00-04:00    0
#                             ..
# 2023-10-10 00:00:00-04:00    0
# 2023-10-11 00:00:00-04:00    0
# 2023-10-12 00:00:00-04:00    0
# 2023-10-13 00:00:00-04:00    0
# 2023-10-16 00:00:00-04:00    0
# Length: 100, dtype: int32

# %%
precision_score(test["Target"] , preds)
# Out:
# 0.8571428571428571

# %%
combined = pd.concat([test["Target"],preds],axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#Building Backtesting System

# %%
def predict(train,test,predictors,model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds,index=test.index , name="Predictions")
    combined = pd.concat([test["Target"],preds],axis=1)
    return combined

# %%
def backtest(data, model, start=250, step=100):
    if not isinstance(start, int) or not isinstance(step, int):
        raise ValueError("Start and step should be integer values.")
    
    if not isinstance(data, (list, np.ndarray, pd.DataFrame)):
        raise ValueError("Data should be a list, numpy array, or pandas DataFrame.")

    all_predictions = []
    for i in range(start, len(data), step):
        train = data[0:i].copy()
        test = data[i:(i+step)].copy()
    return pd.concat(all_predictions)

# %%
predictions = backtest(stock,model,250,100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 predictions = backtest(stock,model,250,100)
#
# Cell In[66], line 12, in backtest(data, model, start, step)
#      10     train = data[0:i].copy()
#      11     test = data[i:(i+step)].copy()
# ---> 12 return pd.concat(all_predictions)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
# ...

# %%
predictions["Predictions"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 predictions["Predictions"].value_counts()
#
# NameError: name 'predictions' is not defined
